# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('main.csv')

# Display the first few rows of the dataframe
print(df.head())

# Display the column name
# Out:
#                                    uuid                     name  \
# 0  eb2fe359-3789-49df-bbe7-af289c547cc4  World Liberty Financial
# 1  3a40a2fe-4904-4836-be28-83e9e1261dd9                Inception
# 2  660ad03f-c1fb-42bd-8d39-dcca245e82ce               World Labs
# 3  c5be4c59-79a6-4109-9703-be3dfd238ddf                 Pump.fun
# 4  602e06d7-375b-4689-bad0-ff591fdfed67                DualEntry
#
#                  permalink                                    founded_on  \
# 0  world-liberty-financial  {'precision': 'year', 'value': '2024-01-01'}
# 1           inception-1dd9  {'precision': 'year', 'value': '2024-01-01'}
# 2               world-labs   {'precision': 'day', 'value': '2024-01-01'}
# 3                 pump-fun  {'precision': 'year', 'value': '2024-01-01'}
# 4                dualentry  {'precision': 'year', 'value': '2024-01-01'}
#
#                                    short_description  \
# 0  World Liberty Financial is a decentralized fin...
# ...

# %%
print(df.columns)
# Out:
# Index(['uuid', 'name', 'permalink', 'founded_on', 'short_description',
#        'website', 'num_employees_enum', 'categories', 'funding_total',
#        'funding_total_numeric', 'num_funding_rounds'],
#       dtype='object')

# %%
print(df['funding_total_numeric'])
# Out:
# 0        950000000.0
# 1         56000000.0
# 2        230000000.0
# 3        600000000.0
# 4        100000000.0
#             ...
# 26007            NaN
# 26008            NaN
# 26009            NaN
# 26010            NaN
# 26011            NaN
# Name: funding_total_numeric, Length: 26012, dtype: float64
